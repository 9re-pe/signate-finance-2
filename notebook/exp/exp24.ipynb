# %% [markdown]
# # TODO
#
# - 有効な特徴量とそうでない特徴量を整理する

# %% [markdown]
# # Setting

# %%
import sys

import numpy as np
import polars as pl
from typing import Final

root_dir = "../../"
if root_dir not in sys.path:
    sys.path.append(root_dir)
from modules import config as cfg
from modules import utils, preprosess, training, predict, metrics, workflow

exp = "exp24"
utils.set_seed(cfg.Params.seed)

# %% [markdown]
# # Read data

# %%
train, test, submit = utils.get_data(debug_mode=False)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Split fold

# %%
train = preprosess.assign_stratified_k_fold(train)

# %% [markdown]
# ## Convert

# %%
train = preprosess.drop_null_columns(train)
test  = preprosess.drop_null_columns(test)

# testのBankStateの"PR"はtrainにないため，一番多いCAに変換
test  = test.with_columns(pl.col("BankState").str.replace("PR", "CA"))

# 地名を座標に変換
train = preprosess.convert_to_latlng(train)
test  = preprosess.convert_to_latlng(test)

# DisbursementDateとApprovalDateを数値に変換
cols  = ["DisbursementDate", "ApprovalDate"]
train = preprosess.convert_date_to_year(train, cols)
test  = preprosess.convert_date_to_year(test, cols)
train = preprosess.convert_date_to_month(train, cols)
test  = preprosess.convert_date_to_month(test, cols)
train = preprosess.convert_date_to_day(train, cols)
test  = preprosess.convert_date_to_day(test, cols)

# 金額データの数値化
cols  = ["DisbursementGross",  "GrAppv", "SBA_Appv"]
train = preprosess.convert_money_data(train, cols)
test  = preprosess.convert_money_data(test, cols)

# 一致しているか
eqs = [
    ["State", "BankState"],
]
train = preprosess.add_eq(train, eqs)
test  = preprosess.add_eq(test, eqs)

# DisbursementDateとApprovalDateの差を計算
train = preprosess.add_diff_disbursement_with_approval(train)
test  = preprosess.add_diff_disbursement_with_approval(test)

# Sectorを職業別にする
train = preprosess.unify_same_sector(train)
test  = preprosess.unify_same_sector(test)

# ラベルデータをSBA_Appvの統計量で置き換える
AGG_NAME: Final[list] = ["mean", "median", "max", "min"]
AGG_COL: Final[str] = "SBA_Appv"
VS_AGG_COLS: Final[list] = [
    'NewExist', 
    'RevLineCr', 
    'LowDoc', 
    'UrbanRural', 
    'CreateJob'
]
train, test = preprosess.convert_aggregation_data(train, test, AGG_COL, VS_AGG_COLS)

# 差の計算
diffs = [
    ["DisbursementGross", "GrAppv"],   # 支払われた額 vs 銀行承認額
    ["DisbursementGross", "SBA_Appv"], # 支払われた額 vs SBA承認額
    ["GrAppv", "SBA_Appv"],            # 銀行承認額 vs SBA承認額
]

# ラベルデータをSBA_Appvの統計量で置き換えたもの vs SBA_Appv
for col_name in VS_AGG_COLS:
    for name in AGG_NAME:
        diff = [AGG_COL, f"{col_name}_{AGG_COL}_{name}"]
        diffs.append(diff)

train = preprosess.add_diff(train, diffs)
test  = preprosess.add_diff(test, diffs)

# 割合の計算
divs = [
    ["DisbursementGross", "Term"],
    ["GrAppv", "Term"],
    ["SBA_Appv", "Term"],
    ["NoEmp", "Term"],
    ["DisbursementGross", "NoEmp"],
    ["GrAppv", "NoEmp"],
    ["SBA_Appv", "NoEmp"],
    ["DisbursementGross_GrAppv_diff", "Term"],
    ["DisbursementGross_SBA_Appv_diff", "Term"],
    ["GrAppv_SBA_Appv_diff", "Term"],
    ["DisbursementGross_GrAppv_diff", "NoEmp"],
    ["DisbursementGross_SBA_Appv_diff", "NoEmp"],
    ["GrAppv_SBA_Appv_diff", "NoEmp"]
]
train = preprosess.add_div(train, divs)
test  = preprosess.add_div(test, divs)

# %% [markdown]
# ## Target encoding

# %%
cols = [
    # "Sector",
    "UrbanRural",
    "RevLineCr",
    "LowDoc",
    "FranchiseCode",
]
train, test = preprosess.target_encoding(train, test, cols)

# %% [markdown]
# ## Label encoding
# CVによるtarget encodingでは同じカテゴリカル変数に異なる値が割り当てられるのでlabel encodingを併用する

# %%
cols = ["RevLineCr", "LowDoc"]
train, test = preprosess.label_encoding(train, test, cols)

# %% [markdown]
# # Drop columns

# %%
# 不要なカラムの削除
del_cols = [
    # 地名系
    "City",
    "State",
    "BankState",
    # d-b-y系
    "DisbursementDate",
    "ApprovalDate",
    "ApprovalFY",
    # ラベルエンコーディング済み
    "RevLineCr",
    "LowDoc",
]

for col_name in VS_AGG_COLS:
    for name in AGG_NAME:
        del_cols.append(f"{col_name}_{AGG_COL}_{name}")

train = train.drop(del_cols)
test  = test.drop(del_cols)

# %% [markdown]
# # Experiments

# %%
utils.ignore_user_warning()

# %%
lgb_params = {
    "objective": "binary",
    "metric": "None",
    "learning_rate": cfg.Params.lgb_learning_rate,
    "max_depth": cfg.Params.lgb_max_depth,
    "n_estimators": cfg.Params.lgb_n_estimators,
    "colsample_bytree": cfg.Params.lgb_colsample_bytree,
    "importance_type": "gain",
    "verbose": -1,
    "seed": cfg.Params.seed,
}
zero_weights = np.arange(0.74, 0.88, 0.01)
df = workflow.search_effective_feature(train, lgb_params=lgb_params, zero_weights=zero_weights)
# Out:
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [679]	valid_0's macroF1: 0.695068
# Time:  25.202[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [554]	valid_0's macroF1: 0.678774
# Time:  17.364[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [697]	valid_0's macroF1: 0.666525
# Time:  20.227[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [480]	valid_0's macroF1: 0.673048
# Time:  16.109[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [577]	valid_0's macroF1: 0.68836
# Time:  18.072[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [719]	valid_0's macroF1: 0.698099
# Time:  18.612[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [892]	valid_0's macroF1: 0.684872
# Time:  19.268[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [711]	valid_0's macroF1: 0.663174
# Time:  12.545[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [385]	valid_0's macroF1: 0.671331
# Time:  6.961[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [521]	valid_0's macroF1: 0.686173
# Time:  8.394[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [560]	valid_0's macroF1: 0.69698
# Time:  8.912[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [998]	valid_0's macroF1: 0.685991
# Time:  11.410[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [561]	valid_0's macroF1: 0.664359
# Time:  8.802[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [987]	valid_0's macroF1: 0.67481
# Time:  11.354[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [545]	valid_0's macroF1: 0.687826
# Time:  9.149[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [755]	valid_0's macroF1: 0.6993
# Time:  10.939[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [765]	valid_0's macroF1: 0.685743
# Time:  11.004[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [544]	valid_0's macroF1: 0.664206
# Time:  8.616[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [454]	valid_0's macroF1: 0.67272
# Time:  7.851[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [431]	valid_0's macroF1: 0.687645
# Time:  7.523[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
#
s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [467]	valid_0's macroF1: 0.687494
# Time:  7.740[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [432]	valid_0's macroF1: 0.663295
# Time:  7.486[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [594]	valid_0's macroF1: 0.676031
# Time:  9.213[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [550]	valid_0's macroF1: 0.684571
# Time:  9.095[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [250]	valid_0's macroF1: 0.693445
# Time:  5.704[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [780]	valid_0's macroF1: 0.687695
# Time:  11.057[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [369]	valid_0's macroF1: 0.661722
# Time:  6.934[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [610]	valid_0's macroF1: 0.674527
# Time:  9.418[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [572]	valid_0's macroF1: 0.682952
# Time:  9.050[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [451]	valid_0's macroF1: 0.693339
# Time:  7.640[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [429]	valid_0's macroF1: 0.690939
# Time:  7.746[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [325]	valid_0's macroF1: 0.660838
# Time:  6.377[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [444]	valid_0's macroF1: 0.673256
# Time:  7.697[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [673]	valid_0's macroF1: 0.682665
# Time:  10.219[s]
# ================================================================================
# ...
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [517]	valid_0's macroF1: 0.67497
# Time:  8.996[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [432]	valid_0's macroF1: 0.680751
# Time:  8.148[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [532]	valid_0's macroF1: 0.69697
# Time:  10.778[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [448]	valid_0's macroF1: 0.686299
# Time:  8.863[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [630]	valid_0's macroF1: 0.662545
# Time:  11.476[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [704]	valid_0's macroF1: 0.677043
# Time:  11.514[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [431]	valid_0's macroF1: 0.682424
# Time:  8.031[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [579]	valid_0's macroF1: 0.6955
# Time:  9.862[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [436]	valid_0's macroF1: 0.686469
# Time:  8.589[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [322]	valid_0's macroF1: 0.663696
# Time:  6.713[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [426]	valid_0's macroF1: 0.675516
# Time:  7.896[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [532]	valid_0's macroF1: 0.681765
# Time:  9.227[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [354]	valid_0's macroF1: 0.694614
# Time:  7.204[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [360]	valid_0's macroF1: 0.683748
# Time:  7.177[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [296]	valid_0's macroF1: 0.662402
# Time:  7.343[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [633]	valid_0's macroF1: 0.677847
# Time:  10.351[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [543]	valid_0's macroF1: 0.687229
# Time:  9.249[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [361]	valid_0's macroF1: 0.694239
# Time:  7.236[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [679]	valid_0's macroF1: 0.685933
# Time:  10.820[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [279]	valid_0's macroF1: 0.661011
# Time:  6.597[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [477]	valid_0's macroF1: 0.676982
# Time:  8.576[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [525]	valid_0's macroF1: 0.684301
# Time:  9.755[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [393]	valid_0's macroF1: 0.693602
# Time:  7.710[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [535]	valid_0's macroF1: 0.688239
# Time:  9.206[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [319]	valid_0's macroF1: 0.661288
# Time:  6.761[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [407]	valid_0's macroF1: 0.678461
# Time:  8.559[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [323]	valid_0's macroF1: 0.684152
# Time:  6.816[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [197]	valid_0's macroF1: 0.692144
# Time:  5.792[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [344]	valid_0's macroF1: 0.68817
# Time:  7.138[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [376]	valid_0's macroF1: 0.658791
# Time:  7.692[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [498]	valid_0's macroF1: 0.675091
# Time:  8.918[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [317]	valid_0's macroF1: 0.68058
# Time:  6.942[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [163]	valid_0's macroF1: 0.690255
# Time:  4.967[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [389]	valid_0's macroF1: 0.683954
# Time:  7.619[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [297]	valid_0's macroF1: 0.656884
# Time:  6.540[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [384]	valid_0's macroF1: 0.675089
# Time:  7.602[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [231]	valid_0's macroF1: 0.676689
# Time:  5.774[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [124]	valid_0's macroF1: 0.686782
# Time:  5.032[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [340]	valid_0's macroF1: 0.678392
# Time:  7.100[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [145]	valid_0's macroF1: 0.654252
# Time:  4.619[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [322]	valid_0's macroF1: 0.671122
# Time:  6.946[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [146]	valid_0's macroF1: 0.672527
# Time:  4.647[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [97]	valid_0's macroF1: 0.686843
# Time:  4.164[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [146]	valid_0's macroF1: 0.673081
# Time:  4.636[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [100]	valid_0's macroF1: 0.654023
# Time:  4.284[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [130]	valid_0's macroF1: 0.666338
# Time:  4.407[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [74]	valid_0's macroF1: 0.671638
# Time:  3.869[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [65]	valid_0's macroF1: 0.686495
# Time:  3.752[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [68]	valid_0's macroF1: 0.668309
# Time:  3.655[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [60]	valid_0's macroF1: 0.654366
# Time:  3.788[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [75]	valid_0's macroF1: 0.66286
# Time:  3.768[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [51]	valid_0's macroF1: 0.668948
# Time:  3.577[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [44]	valid_0's macroF1: 0.686076
# Time:  3.552[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [47]	valid_0's macroF1: 0.668149
# Time:  3.427[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [49]	valid_0's macroF1: 0.653351
# Time:  3.609[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [53]	valid_0's macroF1: 0.663741
# Time:  3.628[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [36]	valid_0's macroF1: 0.666053
# Time:  4.154[s]
# ================================================================================
# FINISH!
# --------------------------------------------------------------------------------
# START fold 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [28]	valid_0's macroF1: 0.682763
# Time:  4.220[s]
# --------------------------------------------------------------------------------
# START fold 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [25]	valid_0's macroF1: 0.666335
# Time:  3.661[s]
# --------------------------------------------------------------------------------
# START fold 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [21]	valid_0's macroF1: 0.652106
# Time:  3.706[s]
# --------------------------------------------------------------------------------
# START fold 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [26]	valid_0's macroF1: 0.662956
# Time:  3.708[s]
# --------------------------------------------------------------------------------
# START fold 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [19]	valid_0's macroF1: 0.666619
# Time:  3.679[s]
# ================================================================================
# FINISH!

# %%
df
# Out:
# shape: (71, 4)
# ┌───────────────────────────────┬──────────┬─────────────┬───────────┐
# │ feature                       ┆ cv_score ┆ zero_weight ┆ diff      │
# │ ---                           ┆ ---      ┆ ---         ┆ ---       │
# │ str                           ┆ f64      ┆ f64         ┆ f64       │
# ╞═══════════════════════════════╪══════════╪═════════════╪═══════════╡
# │ base                          ┆ 0.681836 ┆ 0.76        ┆ 0.0       │
# │ Term                          ┆ 0.681735 ┆ 0.75        ┆ 0.000101  │
# │ NoEmp                         ┆ 0.680982 ┆ 0.77        ┆ 0.000854  │
# │ NewExist                      ┆ 0.682367 ┆ 0.76        ┆ -0.000531 │
# │ …                             ┆ …        ┆ …           ┆ …         │
# │ UrbanRural_MIS_Status_mean    ┆ 0.680893 ┆ 0.77        ┆ 0.000943  │
# │ RevLineCr_MIS_Status_mean     ┆ 0.680853 ┆ 0.77        ┆ 0.000983  │
# │ LowDoc_MIS_Status_mean        ┆ 0.680438 ┆ 0.74        ┆ 0.001398  │
# │ FranchiseCode_MIS_Status_mean ┆ 0.681204 ┆ 0.79        ┆ 0.000632  │
# └───────────────────────────────┴──────────┴─────────────┴───────────┘

# %%
effective = df.filter(pl.col("diff") >= 0)["feature"].to_list()
ineffective = df.filter(pl.col("diff") < 0)["feature"].to_list()

print("Effective features:")
for feature in effective:
    print(f"- {feature}")
print("Ineffective features:")
for feature in ineffective:
    print(f"- {feature}")
# Out:
# Effective features:
# - base
# - Term
# - NoEmp
# - Sector
# - UrbanRural
# - State_lat
# - State_lng
# - BankState_lat
# - DisbursementDateYear
# - ApprovalDateYear
# - ApprovalDateMonth
# - DisbursementDateDay
# - ApprovalDateDay
# - NewExist_SBA_Appv_std
# - RevLineCr_SBA_Appv_std
# - LowDoc_SBA_Appv_std
# - UrbanRural_SBA_Appv_std
# - DisbursementGross_SBA_Appv_diff
# - SBA_Appv_NewExist_SBA_Appv_median_diff
# - SBA_Appv_NewExist_SBA_Appv_min_diff
# - SBA_Appv_RevLineCr_SBA_Appv_mean_diff
# - SBA_Appv_RevLineCr_SBA_Appv_median_diff
# - SBA_Appv_RevLineCr_SBA_Appv_min_diff
# - SBA_Appv_LowDoc_SBA_Appv_mean_diff
# - SBA_Appv_LowDoc_SBA_Appv_max_diff
# - SBA_Appv_LowDoc_SBA_Appv_min_diff
# - SBA_Appv_UrbanRural_SBA_Appv_mean_diff
# - SBA_Appv_UrbanRural_SBA_Appv_median_diff
# - SBA_Appv_UrbanRural_SBA_Appv_min_diff
# - SBA_Appv_CreateJob_SBA_Appv_mean_diff
# - SBA_Appv_CreateJob_SBA_Appv_median_diff
# - SBA_Appv_CreateJob_SBA_Appv_max_diff
# - SBA_Appv_CreateJob_SBA_Appv_min_diff
# - DisbursementGross_Term_div
# - GrAppv_Term_div
# - SBA_Appv_Term_div
# - NoEmp_Term_div
# - DisbursementGross_NoEmp_div
# - GrAppv_NoEmp_div
# - DisbursementGross_GrAppv_diff_Term_div
# - DisbursementGross_SBA_Appv_diff_Term_div
# - DisbursementGross_GrAppv_diff_NoEmp_div
# - DisbursementGross_SBA_Appv_diff_NoEmp_div
# - GrAppv_SBA_Appv_diff_NoEmp_div
# - UrbanRural_MIS_Status_mean
# - RevLineCr_MIS_Status_mean
# - LowDoc_MIS_Status_mean
# - FranchiseCode_MIS_Status_mean
# Ineffective features:
# - NewExist
# - CreateJob
# - RetainedJob
# - FranchiseCode
# - DisbursementGross
# - GrAppv
# - SBA_Appv
# - BankState_lng
# - City_lat
# - City_lng
# - DisbursementDateMonth
# - State_BankState_diff
# - Disbursement_Approval_diff
# - CreateJob_SBA_Appv_std
# - DisbursementGross_GrAppv_diff
# - GrAppv_SBA_Appv_diff
# - SBA_Appv_NewExist_SBA_Appv_mean_diff
# - SBA_Appv_NewExist_SBA_Appv_max_diff
# - SBA_Appv_RevLineCr_SBA_Appv_max_diff
# - SBA_Appv_LowDoc_SBA_Appv_median_diff
# - SBA_Appv_UrbanRural_SBA_Appv_max_diff
# - SBA_Appv_NoEmp_div
# - GrAppv_SBA_Appv_diff_Term_div

# %%
df.write_csv(f"{cfg.DirFile.tmp}exp24_effective_features.csv")
